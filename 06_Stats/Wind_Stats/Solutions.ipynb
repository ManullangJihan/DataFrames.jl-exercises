# %% [markdown]
# # Wind Statistics

# %% [markdown]
# ### Introduction:
#
# The data have been modified to contain some missing values, identified by NaN.
# Using pandas should make this exercise
# easier, in particular for the bonus question.
#
# You should be able to perform all of these operations without using
# a for loop or other looping construct.
#
#
# 1. The data in 'wind.data' has the following format:

# %%
"""
Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL
61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04
61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83
61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71
"""
# Out:
# "Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL\n61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04\n61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83\n61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71\n"

# %% [markdown]
#    The first three columns are year, month and day.  The
#    remaining 12 columns are average windspeeds in knots at 12
#    locations in Ireland on that day.
#
#    More information about the dataset go [here](wind.desc).

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data)

# %% [markdown]
# ### Step 3. Assign it to a variable called data

# %%
# Out:
# 5×15 DataFrame
#  Row │ Yr     Mo     Dy     RPT      VAL      ROS      KIL      SHA      BIR   ⋯
#      │ Int64  Int64  Int64  Float64  Float64  Float64  Float64  Float64  Float ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │    61      1      1    15.04    14.96    13.17     9.29   NaN        9. ⋯
#    2 │    61      1      2    14.71   NaN       10.83     6.5     12.62     7.
#    3 │    61      1      3    18.5     16.88    12.33    10.13    11.17     6.
#    4 │    61      1      4    10.58     6.63    11.75     4.58     4.54     2.
#    5 │    61      1      5    13.33    13.25    11.42     6.17    10.71     8. ⋯
#                                                                7 columns omitted

# %% [markdown]
# ### Step 4. Replace the first 3 columns by a proper Date type. And year 2061? Do we really have data from this year? Fix it.

# %%
# Out:
# 5×13 DataFrame
#  Row │ RPT      VAL      ROS      KIL      SHA      BIR      DUB      CLA      ⋯
#      │ Float64  Float64  Float64  Float64  Float64  Float64  Float64  Float64  ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │   15.04    14.96    13.17     9.29   NaN        9.87    13.67    10.25  ⋯
#    2 │   14.71   NaN       10.83     6.5     12.62     7.67    11.5     10.04
#    3 │   18.5     16.88    12.33    10.13    11.17     6.17    11.25   NaN
#    4 │   10.58     6.63    11.75     4.58     4.54     2.88     8.63     1.79
#    5 │   13.33    13.25    11.42     6.17    10.71     8.21    11.92     6.54  ⋯
#                                                                5 columns omitted

# %% [markdown]
# ### Step 5: Replace NaN values with missing in numeric columns

# %%
# Out:
# 5×13 DataFrame
#  Row │ RPT       VAL         ROS       KIL       SHA         BIR       DUB     ⋯
#      │ Float64?  Float64?    Float64?  Float64?  Float64?    Float64?  Float64 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │    15.04       14.96     13.17      9.29  missing         9.87     13.6 ⋯
#    2 │    14.71  missing        10.83      6.5        12.62      7.67     11.5
#    3 │    18.5        16.88     12.33     10.13       11.17      6.17     11.2
#    4 │    10.58        6.63     11.75      4.58        4.54      2.88      8.6
#    5 │    13.33       13.25     11.42      6.17       10.71      8.21     11.9 ⋯
#                                                                7 columns omitted

# %% [markdown]
# ### Step 6. Compute how many values are missing for each location over the entire record.
# #### They should be ignored in all calculations below.

# %%
# Out:
# Dict{Any, Any} with 13 entries:
#   "RPT"  => 6
#   "CLA"  => 2
#   "DUB"  => 3
#   "MUL"  => 3
#   "KIL"  => 5
#   "SHA"  => 2
#   "MAL"  => 4
#   "VAL"  => 3
#   "ROS"  => 2
#   "BIR"  => 0
#   "date" => 0
#   "CLO"  => 1
#   "BEL"  => 0

# %% [markdown]
# ### Step 6. Compute how many non-missing values there are in total.

# %%
# Out:
# Dict{Any, Any} with 13 entries:
#   "RPT"  => 6568
#   "CLA"  => 6572
#   "DUB"  => 6571
#   "MUL"  => 6571
#   "KIL"  => 6569
#   "SHA"  => 6572
#   "MAL"  => 6570
#   "VAL"  => 6571
#   "ROS"  => 6572
#   "BIR"  => 6574
#   "date" => 6574
#   "CLO"  => 6573
#   "BEL"  => 6574

# %% [markdown]
# ### Step 7. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.
# #### A single number for the entire dataset.

# %%
# Out:
# 10.227883764282167

# %% [markdown]
# ### Step 8. Create a DataFrame called day_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
#
# #### A different set of numbers for each location.

# %%
# Out:
# 5×5 DataFrame
#  Row │ date        min      max      mean      std
#      │ Date        Float64  Float64  Float64   Float64
# ─────┼─────────────────────────────────────────────────
#    1 │ 1961-01-01     9.29    18.5   13.0182   2.80887
#    2 │ 1961-01-02     6.5     17.54  11.3364   3.18899
#    3 │ 1961-01-03     6.17    18.5   11.6418   3.68191
#    4 │ 1961-01-04     1.79    11.75   6.61917  3.19813
#    5 │ 1961-01-05     6.17    13.33  10.63     2.44536

# %% [markdown]
# ### Step 11. Find the average windspeed in January for each location.
# #### Treat January 1961 and January 1962 both as January.

# %%
# Out:
# Dict{String, Float64} with 12 entries:
#   "RPT" => 14.8473
#   "CLA" => 9.51205
#   "DUB" => 11.8194
#   "MUL" => 9.54321
#   "KIL" => 7.1995
#   "SHA" => 11.6677
#   "MAL" => 18.0288
#   "VAL" => 12.9146
#   "ROS" => 13.2996
#   "BIR" => 8.05484
#   "CLO" => 10.0536
#   "BEL" => 14.5505

# %% [markdown]
# ### Step 12. Downsample the record to a yearly frequency for each location.

# %%
# Out:
# 5×13 DataFrame
#  Row │ year   mean_RPT  mean_VAL  mean_ROS  mean_KIL  mean_SHA  mean_BIR  mean ⋯
#      │ Int64  Float64   Float64   Float64   Float64   Float64   Float64   Floa ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │  1961   12.2996   10.3518   11.3624   6.95823   10.8818   7.72973   9.7 ⋯
#    2 │  1962   12.2469   10.1104   11.7327   6.96044   10.6579   7.39307  11.0
#    3 │  1963   12.8135   10.837    12.5412   7.33005   11.7241   8.43471  11.0
#    4 │  1964   12.3637   10.9202   12.1044   6.78779   11.4545   7.57087  10.2
#    5 │  1965   12.4514   11.0755   11.8488   6.85847   11.0248   7.47811  10.6 ⋯
#                                                                6 columns omitted

# %% [markdown]
# ### Step 13. Downsample the record to a monthly frequency for each location.

# %%
# Out:
# 5×13 DataFrame
#  Row │ month  RPT_mean  VAL_mean  ROS_mean  KIL_mean  SHA_mean  BIR_mean  DUB_ ⋯
#      │ Int64  Float64   Float64   Float64   Float64   Float64   Float64   Floa ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │     1   14.8473   12.9146   13.2996   7.1995    11.6677   8.05484  11.8 ⋯
#    2 │     2   13.7109   12.1111   12.8791   6.94241   11.5518   7.63386  11.2
#    3 │     3   13.1587   11.5058   12.6481   7.26591   11.5545   7.95941  11.3
#    4 │     4   12.5556   10.4298   12.2048   6.89804   10.6777   7.44139  10.2
#    5 │     5   11.724    10.1456   11.5504   6.30749   10.2243   6.94206   8.7 ⋯
#                                                                6 columns omitted

# %% [markdown]
# ### Step 14. Downsample the record to a weekly frequency for each location.

# %%
# Out:
# 53×13 DataFrame
#  Row │ week   RPT_mean  VAL_mean  ROS_mean  KIL_mean  SHA_mean  BIR_mean  DUB_ ⋯
#      │ Int64  Float64   Float64   Float64   Float64   Float64   Float64   Floa ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │     1   13.92     11.7109   12.853    6.6173   10.4732    7.57849  11.6 ⋯
#    2 │     2   15.5499   13.3595   14.0163   7.3077   12.1838    8.17024  11.9
#    3 │     3   14.9502   13.2813   13.1668   7.06079  11.9592    8.32024  11.8
#    4 │     4   15.2419   13.5753   13.5545   7.69841  12.1101    8.23516  11.7
#    5 │     5   14.5591   12.8534   13.0708   7.40095  11.8237    8.1654   11.9 ⋯
#    6 │     6   13.2037   11.5085   12.1426   6.46913  11.0255    7.16675  11.1
#    7 │     7   14.5175   12.6813   13.2195   7.14816  12.141     7.90619  11.3
#    8 │     8   13.4229   11.8229   13.3674   7.1424   11.4806    7.72968  11.3
# ...

# %% [markdown]
# ### Step 15. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %%
# Out:
# 52×49 DataFrame
#  Row │ week   RPT_min  VAL_min  ROS_min  KIL_min  SHA_min  BIR_min  DUB_min  C ⋯
#      │ Int64  Float64  Float64  Float64  Float64  Float64  Float64  Float64  F ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │     1     2.62     0.54     3.79     0.37     0.42     0.13     2.62    ⋯
#    2 │     2     2.0      1.08     3.54     0.17     2.29     0.71     1.58
#    3 │     3     1.63     1.5      3.0      0.08     1.17     0.04     0.46
#    4 │     4     0.67     2.83     2.75     0.5      0.92     0.17     0.54
#    5 │     5     2.71     1.17     3.21     0.37     1.25     0.0      1.33    ⋯
#    6 │     6     2.79     0.79     3.67     0.33     3.46     0.13     1.75
#    7 │     7     2.92     2.67     3.5      0.42     1.25     0.0      2.79
#    8 │     8     1.54     0.63     2.37     0.67     1.67     0.04     1.46
#   ⋮  │   ⋮       ⋮        ⋮        ⋮        ⋮        ⋮        ⋮        ⋮       ⋱
# ...
